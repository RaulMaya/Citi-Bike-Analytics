# %%
import pandas as pd

# %%
path1 = 'Output Datasets/2019DS.csv'
path2 = 'Output Datasets/2020DS.csv'

# %%
df1 = pd.read_csv(path1)
df2 = pd.read_csv(path2)

# %%
df1
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3               1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4               1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...              ...                       ...                       ...
# 404942           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 404943           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 404944           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 404945           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 404946           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#         start station id start station name  start station latitude  \
# ...

# %%
df2
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
dataframes = [df1,df2]

# %%
main_df = pd.concat(dataframes)

# %%
main_df.head(50)
# Out:
#     tripduration                 starttime                  stoptime  \
# 0            201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1            505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2            756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3           1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4           1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# 5            737  2019-01-01 12:56:53.2040  2019-01-01 13:09:11.0400
# 6            917  2019-01-01 13:03:44.7760  2019-01-01 13:19:02.7690
# 7           3248  2019-01-01 13:12:03.1280  2019-01-01 14:06:12.0400
# 8           3168  2019-01-01 13:13:12.0450  2019-01-01 14:06:00.4110
# 9            353  2019-01-01 17:07:44.6670  2019-01-01 17:13:38.2640
# 10           503  2019-01-01 17:34:50.9580  2019-01-01 17:43:14.3190
# 11           285  2019-01-01 18:06:03.1680  2019-01-01 18:10:48.5380
# 12           229  2019-01-01 20:05:04.5760  2019-01-01 20:08:53.8630
# ...

# %%
df = main_df.loc[main_df["starting year"]== 2019]

# %%
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3               1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4               1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...              ...                       ...                       ...
# 404942           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 404943           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 404944           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 404945           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 404946           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#         start station id start station name  start station latitude  \
# ...

# %%
main_df.to_csv('Output Datasets/MainDS.csv', index = False)
